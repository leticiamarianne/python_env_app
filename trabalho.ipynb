# %% [markdown]
# ##### **Deslizamento no Maciço do Morro da Cruz**
#
# - 13/09/2022
# - Por volta de 18h30 a Defesa Civil atendeu um chamado de deslizamento

# %%
# Importanto as bibliotecas

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
# Lendo todos os arquivos

pasta = r'C:\Users\leti_\OneDrive\Documentos\python_env_app\Trabalho01'
arquivos = [ fname for fname in os.listdir(pasta) if fname.endswith('.csv')]
print(arquivos)
# Out:
# ['data_jan_2025.csv']

# %%
# Unindo todos os arquivos em um DataFrame

dfs = []
for arq in arquivos:
    #estacao = arq.replace('.csv', '')               # Nome da estacao
    temp = pd.read_csv(os.path.join(pasta, arq), sep=';')    # Lendo o arquivo
    dfs.append(temp)                                # Guardando o DataFrame numa lista
#df = df.drop(columns=['Unnamed: 8', 'Unnamed: 9'])
df.head()
# Out:
#        municipio  codEstacao  uf nomeEstacao latitude longitude  \
# 0  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 1  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 2  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 3  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 4  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
#
#              datahora  precipitacao       data      hora
# 0 2022-09-01 00:20:00           0.0 2022-09-01  00:20:00
# 1 2022-09-01 01:20:00           0.0 2022-09-01  01:20:00
# 2 2022-09-01 02:20:00           0.0 2022-09-01  02:20:00
# 3 2022-09-01 03:20:00           0.0 2022-09-01  03:20:00
# 4 2022-09-01 04:20:00           0.0 2022-09-01  04:20:00

# %%
# Convertendo para DateTime e criando data e hora separados

df['datahora'] = pd.to_datetime(df['datahora'])
df['data'] = df['datahora'].dt.date
df['hora'] = df['datahora'].dt.time

{df.rename(columns={'valorMedida':'precipitacao'}, inplace=True)}

df['precipitacao'] = pd.to_numeric(df['precipitacao'], errors='coerce')

df.head()
# Out:
#        municipio  codEstacao  uf nomeEstacao latitude longitude  \
# 0  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 1  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 2  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 3  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 4  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
#
#              datahora  precipitacao        data      hora
# 0 2022-09-01 00:20:00           0.0  2022-09-01  00:20:00
# 1 2022-09-01 01:20:00           0.0  2022-09-01  01:20:00
# 2 2022-09-01 02:20:00           0.0  2022-09-01  02:20:00
# 3 2022-09-01 03:20:00           0.0  2022-09-01  03:20:00
# 4 2022-09-01 04:20:00           0.0  2022-09-01  04:20:00

# %%
# Definindo a data do deslizamento - 13 de setembro

evento = pd.to_datetime("2022-09-14")
df_filtrado = df[df['data'] <= evento]

df.head()
# Out:
#        municipio  codEstacao  uf nomeEstacao latitude longitude  \
# 0  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 1  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 2  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 3  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
# 4  FLORIANOPOLIS  420540702A  SC   Coqueiros  -27,599   -48,573
#
#              datahora  precipitacao       data      hora
# 0 2022-09-01 00:20:00           0.0 2022-09-01  00:20:00
# 1 2022-09-01 01:20:00           0.0 2022-09-01  01:20:00
# 2 2022-09-01 02:20:00           0.0 2022-09-01  02:20:00
# 3 2022-09-01 03:20:00           0.0 2022-09-01  03:20:00
# 4 2022-09-01 04:20:00           0.0 2022-09-01  04:20:00

# %%
# Estatísticas básicas - média, desvio padrão, máximo e total acumulado em cada estação

estat = df_filtrado.groupby('nomeEstacao')['precipitacao'].agg(['mean', 'std', 'max', 'sum']).reset_index()
#print(estat)

# Criando tabela
estat = estat.rename(columns={
    'nomeEstacao': 'Estação',
    'mean': 'Média',
    'std': 'Desvio Padrão',
    'max': 'Máximo',
    'sum': 'Acumulado'
})

# Personalizando
estat_styled = (
    estat.style
        .format({
        'Média': '{:.2f}',
        'Desvio Padrão': '{:.2f}',
        'Máximo': '{:.2f}',
        'Acumulado': '{:.2f}'
    })
    .set_caption("<div style='text-align:center; font-weight:bold; font-size:18px;'>Estatísticas básicas de precipitação</div>")
    .set_table_styles([
        {'selector': 'td', 'props': [('text-align', 'center'), ('padding', '8px')]},
        {'selector': 'th', 'props': [('text-align', 'center'), ('padding', '8px'), ('background-color', '#f2f2f2')]},
        {'selector': 'th.col0', 'props': [('width', '110px')]},
        {'selector': 'th.col1', 'props': [('width', '100px')]},
        {'selector': 'th.col2', 'props': [('width', '100px')]},
        {'selector': 'th.col3', 'props': [('width', '100px')]},
        {'selector': 'th.col4', 'props': [('width', '100px')]},
    ])
    .hide(axis='index')
)
estat_styled

#estat.to_csv(r"C:\Users\leti_\OneDrive\Documentos\python_env_app\outputs"+'/'+'univariada.csv')
# Out:
# <style type="text/css">
# #T_64524 td {
#   text-align: center;
#   padding: 8px;
# }
# #T_64524 th {
#   text-align: center;
#   padding: 8px;
#   background-color: #f2f2f2;
# }
# #T_64524 th.col0 {
#   width: 110px;
# }
# #T_64524 th.col1 {
#   width: 100px;
# }
# #T_64524 th.col2 {
#   width: 100px;
# }
# #T_64524 th.col3 {
#   width: 100px;
# }
# #T_64524 th.col4 {
#   width: 100px;
# }
# </style>
# <table id="T_64524">
#   <caption><div style='text-align:center; font-weight:bold; font-size:18px;'>Estatísticas básicas de precipitação</div></caption>
#   <thead>
#     <tr>
#       <th id="T_64524_level0_col0" class="col_heading level0 col0" >Estação</th>
#       <th id="T_64524_level0_col1" class="col_heading level0 col1" >Média</th>
#       <th id="T_64524_level0_col2" class="col_heading level0 col2" >Desvio Padrão</th>
#       <th id="T_64524_level0_col3" class="col_heading level0 col3" >Máximo</th>
#       <th id="T_64524_level0_col4" class="col_heading level0 col4" >Acumulado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_64524_row0_col0" class="data row0 col0" >Agronomica</td>
#       <td id="T_64524_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_64524_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_64524_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_64524_row0_col4" class="data row0 col4" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_64524_row1_col0" class="data row1 col0" >Areias_Campeche</td>
#       <td id="T_64524_row1_col1" class="data row1 col1" >0.10</td>
#       <td id="T_64524_row1_col2" class="data row1 col2" >0.22</td>
#       <td id="T_64524_row1_col3" class="data row1 col3" >1.77</td>
#       <td id="T_64524_row1_col4" class="data row1 col4" >44.05</td>
#     </tr>
#     <tr>
#       <td id="T_64524_row2_col0" class="data row2 col0" >Canasvieiras</td>
#       <td id="T_64524_row2_col1" class="data row2 col1" >0.15</td>
#       <td id="T_64524_row2_col2" class="data row2 col2" >0.31</td>
#       <td id="T_64524_row2_col3" class="data row2 col3" >3.94</td>
#       <td id="T_64524_row2_col4" class="data row2 col4" >72.37</td>
#     </tr>
#     <tr>
#       <td id="T_64524_row3_col0" class="data row3 col0" >Coqueiros</td>
#       <td id="T_64524_row3_col1" class="data row3 col1" >0.01</td>
#       <td id="T_64524_row3_col2" class="data row3 col2" >0.05</td>
#       <td id="T_64524_row3_col3" class="data row3 col3" >0.20</td>
#       <td id="T_64524_row3_col4" class="data row3 col4" >4.20</td>
#     </tr>
#     <tr>
#       <td id="T_64524_row4_col0" class="data row4 col0" >Rio_Vermelho</td>
#       <td id="T_64524_row4_col1" class="data row4 col1" >0.14</td>
#       <td id="T_64524_row4_col2" class="data row4 col2" >0.28</td>
#       <td id="T_64524_row4_col3" class="data row4 col3" >3.55</td>
#       <td id="T_64524_row4_col4" class="data row4 col4" >69.15</td>
#     </tr>
#     <tr>
#       <td id="T_64524_row5_col0" class="data row5 col0" >Rodovia_SC406</td>
#       <td id="T_64524_row5_col1" class="data row5 col1" >0.10</td>
#       <td id="T_64524_row5_col2" class="data row5 col2" >0.26</td>
#       <td id="T_64524_row5_col3" class="data row5 col3" >2.36</td>
#       <td id="T_64524_row5_col4" class="data row5 col4" >44.43</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Acumulados móveis (3, 7 e 13 dias)

# Criando um dicionário para armazenar resultados
acum_evento = {}

# Calculando acumulado para cada estação
for estacao, grupo in df_filtrado.groupby('nomeEstacao'):
    grupo = grupo.sort_values('data')

    # Filtro dos últimos 3, 7 e 13 dias
    ultimos_13d = grupo[(grupo['data'] > evento - pd.Timedelta(days=13)) & (grupo['data'] <= evento)]
    ultimos_7d = grupo[(grupo['data'] > evento - pd.Timedelta(days=7)) & (grupo['data'] <= evento)]
    ultimos_3d = grupo[(grupo['data'] > evento - pd.Timedelta(days=3)) & (grupo['data'] <= evento)]

    acum_evento[estacao] = {
        'acum_13d': ultimos_13d['precipitacao'].sum(),
        'acum_7d': ultimos_7d['precipitacao'].sum(),
        'acum_3d': ultimos_3d['precipitacao'].sum()
    }

# Transformando o dicionário em dataframe
acum_evento_df = pd.DataFrame.from_dict(acum_evento, orient='index').reset_index()
acum_evento_df.rename(columns={'index': 'nomeEstacao'}, inplace=True)

#print(acum_evento_df)

# Criando tabela

# Renomeando colunas
acum_evento_df = acum_evento_df.rename(columns={
    'nomeEstacao': 'Estação',
    'acum_13d': '13 dias',
    'acum_7d': '7 dias',
    'acum_3d': '3 dias'
})
acum_evento_df_styled = (
    acum_evento_df.style
    .format({
        '13 dias': '{:.2f}',
        '7 dias': '{:.2f}',
        '3 dias': '{:.2f}'
    })
    .set_caption("<div style='text-align:center; font-weight:bold; font-size:18px;'>Acumulados de precipitação (mm)</div>")
    .set_table_styles([
        {'selector': 'td', 'props': [('text-align', 'center'), ('padding', '8px')]},
        {'selector': 'th', 'props': [('text-align', 'center'), ('padding', '8px'), ('background-color', '#f2f2f2')]},
        {'selector': 'th.col0', 'props': [('width', '110px')]},
        {'selector': 'th.col1', 'props': [('width', '100px')]},
        {'selector': 'th.col2', 'props': [('width', '100px')]},
        {'selector': 'th.col3', 'props': [('width', '100px')]},
        {'selector': 'th.col4', 'props': [('width', '100px')]},
    ])
    .hide(axis='index')
)
acum_evento_df_styled
# Out:
# <style type="text/css">
# #T_c6159 td {
#   text-align: center;
#   padding: 8px;
# }
# #T_c6159 th {
#   text-align: center;
#   padding: 8px;
#   background-color: #f2f2f2;
# }
# #T_c6159 th.col0 {
#   width: 110px;
# }
# #T_c6159 th.col1 {
#   width: 100px;
# }
# #T_c6159 th.col2 {
#   width: 100px;
# }
# #T_c6159 th.col3 {
#   width: 100px;
# }
# #T_c6159 th.col4 {
#   width: 100px;
# }
# </style>
# <table id="T_c6159">
#   <caption><div style='text-align:center; font-weight:bold; font-size:18px;'>Acumulados de precipitação (mm)</div></caption>
#   <thead>
#     <tr>
#       <th id="T_c6159_level0_col0" class="col_heading level0 col0" >Estação</th>
#       <th id="T_c6159_level0_col1" class="col_heading level0 col1" >13 dias</th>
#       <th id="T_c6159_level0_col2" class="col_heading level0 col2" >7 dias</th>
#       <th id="T_c6159_level0_col3" class="col_heading level0 col3" >3 dias</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c6159_row0_col0" class="data row0 col0" >Agronomica</td>
#       <td id="T_c6159_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_c6159_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_c6159_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_c6159_row1_col0" class="data row1 col0" >Areias_Campeche</td>
#       <td id="T_c6159_row1_col1" class="data row1 col1" >44.05</td>
#       <td id="T_c6159_row1_col2" class="data row1 col2" >26.85</td>
#       <td id="T_c6159_row1_col3" class="data row1 col3" >26.85</td>
#     </tr>
#     <tr>
#       <td id="T_c6159_row2_col0" class="data row2 col0" >Canasvieiras</td>
#       <td id="T_c6159_row2_col1" class="data row2 col1" >72.37</td>
#       <td id="T_c6159_row2_col2" class="data row2 col2" >44.72</td>
#       <td id="T_c6159_row2_col3" class="data row2 col3" >38.80</td>
#     </tr>
#     <tr>
#       <td id="T_c6159_row3_col0" class="data row3 col0" >Coqueiros</td>
#       <td id="T_c6159_row3_col1" class="data row3 col1" >4.20</td>
#       <td id="T_c6159_row3_col2" class="data row3 col2" >0.60</td>
#       <td id="T_c6159_row3_col3" class="data row3 col3" >0.40</td>
#     </tr>
#     <tr>
#       <td id="T_c6159_row4_col0" class="data row4 col0" >Rio_Vermelho</td>
#       <td id="T_c6159_row4_col1" class="data row4 col1" >69.15</td>
#       <td id="T_c6159_row4_col2" class="data row4 col2" >44.76</td>
#       <td id="T_c6159_row4_col3" class="data row4 col3" >30.56</td>
#     </tr>
#     <tr>
#       <td id="T_c6159_row5_col0" class="data row5 col0" >Rodovia_SC406</td>
#       <td id="T_c6159_row5_col1" class="data row5 col1" >44.43</td>
#       <td id="T_c6159_row5_col2" class="data row5 col2" >26.42</td>
#       <td id="T_c6159_row5_col3" class="data row5 col3" >26.42</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Acumulado diário por estação
df_diario = df_filtrado.groupby(['nomeEstacao', 'data'], as_index=False)['precipitacao'].sum()

# Gráfico da precipitação diária

plt.figure(figsize=(10,5))

#paleta de cores
cores = sns.color_palette("pastel", len(df_diario['nomeEstacao'].unique()))

# Criando barras com cores diferentes
for est,cor in zip(df_diario['nomeEstacao'].unique(), cores):
    dados = df_diario[df_diario['nomeEstacao'] == est]
    plt.plot(dados['data'], dados['precipitacao'], label=est, color=cor, alpha=0.9)

# Personalização geral
plt.title('Precipitação Diária em Florianópolis', fontsize=12, fontweight='bold')
plt.xlabel('Data', fontsize=11)
plt.ylabel('Precipitação (mm)', fontsize=11)
plt.xlim(df_diario['data'].min(), df_diario['data'].max())
plt.ylim(0, df_diario['precipitacao'].max() * 1.05)
plt.xticks(rotation=45)
plt.legend(frameon=False)
plt.tight_layout()
plt.savefig(r"C:\Users\Leti_\OneDrive\Documentos\python_env_app\outputs\precipitacao_diaria.png")
plt.show()

# %%
# Definindo linhas e colunas
colunas = ['13 dias', '7 dias', '3 dias']
titulos = ['Acumulado 13 dias', 'Acumulado 7 dias', 'Acumulado 3 dias']

# Escolhendo paleta de cores
cores = sns.color_palette("Set2", len(acum_evento_df))

# Criando figura com 3 subgráficos
fig, axes = plt.subplots(1, 3, figsize=(10, 5))

# Gerando as barras
for i, (ax, col, titulo) in enumerate(zip(axes, colunas, titulos)):
    x = range(len(acum_evento_df['Estação']))
    ax.bar(x, acum_evento_df[col], color=cores)

    # Eixo X - centralizado e rotacionado
    ax.set_xticks(x)
    ax.set_xticklabels(acum_evento_df['Estação'], rotation=45, ha='center', fontsize=10)

    # Títulos e rótulos
    ax.set_title(titulo, fontsize=11, fontweight='bold')
    ax.set_ylabel('Precipitação (mm)' if i == 0 else "", fontsize=10)

# Título principal
fig.suptitle('Acumulados de Precipitação até o Deslizamento (13/09/2025)', fontsize=13, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig(r"C:\Users\Leti_\OneDrive\Documentos\python_env_app\outputs\acumulado_dias.png")
plt.show()

# %%
# Acumulados de 72, 48 e 24 horas

acum_evento_horas = {}

# Calculando acumulado para cada estação
for estacao, grupo in df_filtrado.groupby('nomeEstacao'):
    grupo = grupo.sort_values('data')

    # Filtro dos últimos 3, 7 e 13 dias antes do desastre
    hora_72 = grupo[(grupo['data'] > evento - pd.Timedelta(days=3)) & (grupo['data'] <= evento)]
    hora_48 = grupo[(grupo['data'] > evento - pd.Timedelta(days=2)) & (grupo['data'] <= evento)]
    hora_24 = grupo[(grupo['data'] > evento - pd.Timedelta(days=1)) & (grupo['data'] <= evento)]

    acum_evento_horas[estacao] = {
        'acum_72h': hora_72['precipitacao'].sum(),
        'acum_48h': hora_48['precipitacao'].sum(),
        'acum_24h': hora_24['precipitacao'].sum()
    }

# Transformando o dicionário em dataframe
acum_evento_horas_df = pd.DataFrame.from_dict(acum_evento_horas, orient='index').reset_index()
acum_evento_horas_df.rename(columns={'index': 'nomeEstacao'}, inplace=True)

#print(acum_evento_df)

# Criando tabela

# Renomeando colunas
acum_evento_horas_df = acum_evento_horas_df.rename(columns={
    'nomeEstacao': 'Estação',
    'acum_72h': '72 horas',
    'acum_48h': '48 horas',
    'acum_24h': '24 horas'
})

# Personalizando
acum_evento_horas_df_styled = (
    acum_evento_horas_df.style
    .format({
        '72 horas': '{:.2f}',
        '48 horas': '{:.2f}',
        '24 horas': '{:.2f}'
    })
    .set_caption("<div style='text-align:center; font-weight:bold; font-size:18px;'>Acumulados de precipitação (mm)</div>")
    .set_table_styles([
        {'selector': 'td', 'props': [('text-align', 'center'), ('padding', '8px')]},
        {'selector': 'th', 'props': [('text-align', 'center'), ('padding', '8px'), ('background-color', '#f2f2f2')]},
        {'selector': 'th.col0', 'props': [('width', '110px')]},
        {'selector': 'th.col1', 'props': [('width', '100px')]},
        {'selector': 'th.col2', 'props': [('width', '100px')]},
        {'selector': 'th.col3', 'props': [('width', '100px')]},
        {'selector': 'th.col4', 'props': [('width', '100px')]},
    ])
    .hide(axis='index')
)
acum_evento_horas_df_styled
# Out:
# <style type="text/css">
# #T_bd108 td {
#   text-align: center;
#   padding: 8px;
# }
# #T_bd108 th {
#   text-align: center;
#   padding: 8px;
#   background-color: #f2f2f2;
# }
# #T_bd108 th.col0 {
#   width: 110px;
# }
# #T_bd108 th.col1 {
#   width: 100px;
# }
# #T_bd108 th.col2 {
#   width: 100px;
# }
# #T_bd108 th.col3 {
#   width: 100px;
# }
# #T_bd108 th.col4 {
#   width: 100px;
# }
# </style>
# <table id="T_bd108">
#   <caption><div style='text-align:center; font-weight:bold; font-size:18px;'>Acumulados de precipitação (mm)</div></caption>
#   <thead>
#     <tr>
#       <th id="T_bd108_level0_col0" class="col_heading level0 col0" >Estação</th>
#       <th id="T_bd108_level0_col1" class="col_heading level0 col1" >72 horas</th>
#       <th id="T_bd108_level0_col2" class="col_heading level0 col2" >48 horas</th>
#       <th id="T_bd108_level0_col3" class="col_heading level0 col3" >24 horas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bd108_row0_col0" class="data row0 col0" >Agronomica</td>
#       <td id="T_bd108_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_bd108_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_bd108_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_bd108_row1_col0" class="data row1 col0" >Areias_Campeche</td>
#       <td id="T_bd108_row1_col1" class="data row1 col1" >26.85</td>
#       <td id="T_bd108_row1_col2" class="data row1 col2" >4.74</td>
#       <td id="T_bd108_row1_col3" class="data row1 col3" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_bd108_row2_col0" class="data row2 col0" >Canasvieiras</td>
#       <td id="T_bd108_row2_col1" class="data row2 col1" >38.80</td>
#       <td id="T_bd108_row2_col2" class="data row2 col2" >4.14</td>
#       <td id="T_bd108_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_bd108_row3_col0" class="data row3 col0" >Coqueiros</td>
#       <td id="T_bd108_row3_col1" class="data row3 col1" >0.40</td>
#       <td id="T_bd108_row3_col2" class="data row3 col2" >0.20</td>
#       <td id="T_bd108_row3_col3" class="data row3 col3" >0.20</td>
#     </tr>
#     <tr>
#       <td id="T_bd108_row4_col0" class="data row4 col0" >Rio_Vermelho</td>
#       <td id="T_bd108_row4_col1" class="data row4 col1" >30.56</td>
#       <td id="T_bd108_row4_col2" class="data row4 col2" >5.70</td>
#       <td id="T_bd108_row4_col3" class="data row4 col3" >0.00</td>
#     </tr>
#     <tr>
#       <td id="T_bd108_row5_col0" class="data row5 col0" >Rodovia_SC406</td>
#       <td id="T_bd108_row5_col1" class="data row5 col1" >26.42</td>
#       <td id="T_bd108_row5_col2" class="data row5 col2" >2.57</td>
#       <td id="T_bd108_row5_col3" class="data row5 col3" >0.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Definindo linhas e colunas
colunashoras = ['72 horas', '48 horas', '24 horas']
tituloshoras = ['72 horas', '48 horas', '24 horas']

# Escolhendo paleta de cores 
coreshoras = sns.color_palette("Set2", len(acum_evento_horas_df))

# Criando figura com 3 subgráficos
fig, axes = plt.subplots(1, 3, figsize=(10, 5))

# Gerando as barras
for i, (ax, colhora, titulohora) in enumerate(zip(axes, colunashoras, tituloshoras)):
    xhora = range(len(acum_evento_horas_df['Estação']))
    ax.bar(xhora, acum_evento_horas_df[colhora], color=coreshoras)

    # Eixo X - centralizado e rotacionado
    ax.set_xticks(xhora)
    ax.set_xticklabels(acum_evento_horas_df['Estação'], rotation=45, ha='center', fontsize=10)

    # Títulos e rótulos
    ax.set_title(titulohora, fontsize=11, fontweight='bold')
    ax.set_ylabel('Precipitação (mm)' if i == 0 else "", fontsize=10)

# Título principal
fig.suptitle('Acumulados de Precipitação', fontsize=13, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig(r"C:\Users\Leti_\OneDrive\Documentos\python_env_app\outputs\acumulado_horas.png")
plt.show()
